# %% [markdown]
# ## Quiz #0302

# %% [markdown]
# ### "Bolt specification"

# %%
import numpy as np
import scipy.stats as st

# %% [markdown]
# #### Answer the following questions by providing Python code:

# %% [markdown]
# According to the specification sheet, the average weight of the bolts is $\mu = 30$gr with $\sigma = 2$gr.<br>
# Suppose that a sample of 50 bolts is drawn.

# %%
mu = 30
sigma = 2
n = 50
df = n-1

# %% [markdown]
# 1). What is the probability that the sample mean is **between** 29.8gr and 30.2gr? (Use Standard Normal and Student-t)

# %%
# Using the Standard Normal.
st.norm.cdf(30.2, mu, sigma) - st.norm.cdf(29.8, mu, sigma)
# Out:
# 0.0796556745540577

# %%
# Using the Student-t.
SEM = sigma/np.sqrt(n)
Z1 = (30.2-mu)/SEM
Z2 = (28.2-mu)/SEM

st.t.cdf(Z1,df) - st.t.cdf(Z2,df)
# Out:
# 0.7585751825723914

# %% [markdown]
# 2). What is the probability that the sample mean is **larger** than 30.5gr? (Use Standard Normal and Student-t)

# %%
# Using the Standard Normal.
st.norm.cdf(30.5, mu, sigma)
# Out:
# 0.5987063256829237

# %%
# Using the Student-t.
Z = (30.5-mu)/SEM

st.t.cdf(Z,df)
# Out:
# 0.9583369201292453
