# %% [markdown]
# ## Quiz #0305

# %% [markdown]
# ### "Correlation and interval estimation"

# %%
import numpy as np
import scipy.stats as st

# %% [markdown]
# #### Answer the following questions by providing Python code:

# %% [markdown]
# Calculate the 95% and 99% conficence intervals for the Pearson correlation. <br>
# Discuss whether the confidence interval includes zero or not.

# %% [markdown]
# 1). When the sample size $n = 30$ and the sample correlation $r = 0.45$:

# %%
n = 30
r = 0.45
Z = np.arctanh(r)
SEM_Z = 1/np.sqrt(n-3)

# %%
# 95% confidence interval. 
print('low=' , np.tanh(Z-st.norm.ppf(0.975)*SEM_Z) , 'high=' , np.tanh(Z+st.norm.ppf(0.975)*SEM_Z))
# Out:
# low= 0.10709278247377604 high= 0.6972330057657297

# %%
# 99% confidence interval. 
print('low=' , np.tanh(Z-st.norm.ppf(0.995)*SEM_Z) , 'high=' , np.tanh(Z+st.norm.ppf(995)*SEM_Z))
# Out:
# low= -0.011017856139532253 high= nan

# %% [markdown]
# 2). When the sample size $n = 300$ and the sample correlation $r = -0.2$:

# %%
n = 300
r = -0.2
Z = np.arctanh(r)
SEM_Z = 1/np.sqrt(n-3)

# %%
# 95% confidence interval. # 95% confidence interval. 
print('low=' , np.tanh(Z-st.norm.ppf(0.975)*SEM_Z) , 'high=' , np.tanh(Z+st.norm.ppf(0.975)*SEM_Z))
# Out:
# low= -0.3063036232659099 high= -0.08876963035471497

# %%
# 99% confidence interval. 
print('low=' , np.tanh(Z-st.norm.ppf(0.995)*SEM_Z) , 'high=' , np.tanh(Z+st.norm.ppf(995)*SEM_Z))
# Out:
# low= -0.3383228071595094 high= nan
